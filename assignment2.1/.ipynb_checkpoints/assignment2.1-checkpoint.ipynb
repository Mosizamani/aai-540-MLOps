# %%
# %pip install boto3 "sagemaker<3.0" pyathena pandas

# %%
# import os
os._exit(00)

# %%
import os
import boto3
import sagemaker

# Suppress v2 deprecation warning if on SageMaker v2
os.environ["SAGEMAKER_SUPPRESS_V2_WARNING"] = "1"

# %%
# Initialize low-level AWS session (resolves credentials & region from IAM role)
session = boto3.session.Session()

# Extract current active AWS region (e.g., 'us-east-1')
region = session.region_name

# Initialize high-level SageMaker context (wraps boto3 clients)
sagemaker_session = sagemaker.Session()

# create 'sagemaker-{region}-{account_id}'
bucket = sagemaker_session.default_bucket()

# %%
# Define S3 prefix and paths
s3_data_prefix = "homework-2-1/data"
s3_staging_dir = f"s3://{bucket}/athena/staging/"

# %%
# Copy homework dataset to S3 bucket
# !aws s3 cp ../../aai-540-homework/homework-2-1/data/ s3://{bucket}/{s3_data_prefix}/ --recursive
# Out:
# upload: data/dataset.csv to s3://sagemaker-us-east-1-682123396235/homework-2-1/data/dataset.csv

# %%
import warnings
warnings.filterwarnings(
    "ignore",
    message=".*pandas only supports SQLAlchemy connectable.*",
    category=UserWarning
)

# %%
import warnings
from pyathena import connect
import pandas as pd

# Suppress pandas DBAPI connection warning
warnings.filterwarnings("ignore", category=UserWarning, module="pandas")

database_name = "dsoaws_hw"
table_name_csv = "spotify_tracks"

# Connect to Athena
conn = connect(
    s3_staging_dir=s3_staging_dir,
    region_name=region
)

# Create Database
create_db_statement = f"CREATE DATABASE IF NOT EXISTS {database_name}"
pd.read_sql(create_db_statement, conn)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# Verify database creation
databases = pd.read_sql("SHOW DATABASES", conn)

if database_name in databases.iloc[:, 0].values:
    print(f"Database '{database_name}' successfully created/verified!")
else:
    print(f"Warning: Database '{database_name}' was not found in SHOW DATABASES.")
# Out:
# Database 'dsoaws_hw' successfully created/verified!

# %%
statement = "SHOW DATABASES"

df_show = pd.read_sql(statement, conn)
df_show.head(5)
# Out:
#   database_name
# 0       default
# 1        dsoaws
# 2     dsoaws_hw

# %%
create_table_statement = f"""
CREATE EXTERNAL TABLE IF NOT EXISTS {database_name}.{table_name_csv} (
    track_id STRING,
    artists STRING,
    album_name STRING,
    track_name STRING,
    popularity INT,
    duration_ms INT,
    explicit BOOLEAN,
    danceability DOUBLE,
    energy DOUBLE,
    key INT,
    loudness DOUBLE,
    mode INT,
    speechiness DOUBLE,
    acousticness DOUBLE,
    instrumentalness DOUBLE,
    liveness DOUBLE,
    valence DOUBLE,
    tempo DOUBLE,
    time_signature INT,
    track_genre STRING
)
ROW FORMAT DELIMITED
FIELDS TERMINATED BY ','
LINES TERMINATED BY '\\n'
LOCATION 's3://{bucket}/{s3_data_prefix}/'
TBLPROPERTIES ('skip.header.line.count'='1')
"""

pd.read_sql(create_table_statement, conn)

# Verify table creation
df_show = pd.read_sql(f"SHOW TABLES IN {database_name}", conn)
print(df_show)
# Out:
#          tab_name
# 0  spotify_tracks

# %%
base_query = f"SELECT * FROM {database_name}.{table_name_csv}"
df_all = pd.read_sql(base_query, conn)

# Preview the first 5 rows
print(df_all.head())

# Check the row and column count
print(f"Loaded {df_all.shape[0]:,} rows and {df_all.shape[1]} columns.")
# Out:
#   track_id                 artists              album_name  \
# 0        0  5SuOikwiRyPMVoIQDJUgSV             Gen Hoshino
# 1        1  4qPNDBW1i3p13qLCt0Ki3A            Ben Woodward
# 2        2  1iJBSr7s7jYXzM8EGcbK5b  Ingrid Michaelson;ZAYN
# 3        3  6lfxq3CG4xtTiEg7opyCyx            Kina Grannis
# 4        4  5vjLSffimiIP26QG5WcN2K        Chord Overstreet
#
#                                           track_name  popularity  duration_ms  \
# 0                                             Comedy         NaN         73.0
# 1                                   Ghost (Acoustic)         NaN         55.0
# 2                                     To Begin Again         NaN         57.0
# 3  Crazy Rich Asians (Original Motion Picture Sou...         NaN         71.0
# 4                                            Hold On         NaN         82.0
#
#   explicit  danceability  energy  key  loudness  mode  speechiness  \
# 0     None           NaN   0.676  0.0       1.0  -6.0          0.0
# 1     None           NaN   0.420  0.0       1.0 -17.0          1.0
# 2     None           NaN   0.438  0.0       0.0  -9.0          1.0
# 3     None           NaN   0.266  0.0       0.0 -18.0          1.0
# 4     None           NaN   0.618  0.0       2.0  -9.0          1.0
#
#    acousticness  instrumentalness  liveness  valence  tempo  time_signature  \
# 0        0.1430            0.0322  0.000001   0.3580  0.715            87.0
# 1        0.0763            0.9240  0.000006   0.1010  0.267            77.0
# 2        0.0557            0.2100  0.000000   0.1170  0.120            76.0
# 3        0.0363            0.9050  0.000071   0.1320  0.143           181.0
# 4        0.0526            0.4690  0.000000   0.0829  0.167           119.0
#
#   track_genre
# 0           4
# 1           4
# 2           4
# 3           3
# 4           4
# Loaded 114,000 rows and 20 columns.

# %%
statement_1 = f"""
SELECT artists, track_name, popularity
FROM {database_name}.{table_name_csv}
WHERE popularity >= 99
"""
print("SQL Answer", "\n")
df_sql_1 = pd.read_sql(statement_1, conn)
print(df_sql_1)
# Out:
# SQL Answer
#
#                    artists                     track_name  popularity
# 0   2mHWjrN4rIL8vbWt0Od9Ux  Falling into your eyes Record        3636
# 1   2lR5gm2BEy1PFxPSuyTWBU                            Boa         442
# 2   42khMXWZYiyt9Yaw3lKgz5                           No 2        2176
# 3   2QPBB9Vp5ZpcvLgbrnlNCc            Urban Funk Breaks 2         777
# 4   0zmU4bGV5OmfBsOU9KPfxy                          Swing        1984
# ..                     ...                            ...         ...
# 93  5HLT3oPj9pObEIKslHGmQd                      Bumfuzzle         368
# 94  5Qe2ogGBgher2D1U1k7Ezc             Great Good Five Ok        2020
# 95  2XWjPtKdi5sucFYtVav07d                            365         365
# 96  3JZjPBwqL5F4PE55nm8iNV                       Geogaddi        1969
# 97  36ROZuJyblakeB5BJijGjG                           1500        1500
#
# [98 rows x 3 columns]

# %%
df_pds_1 = df_all[df_all['popularity'] >= 99][['artists', 'track_name', 'popularity']]

print("Pandas Answer", "\n")
print(df_pds_1)
# Out:
# Pandas Answer
#
#                        artists                     track_name  popularity
# 821     2mHWjrN4rIL8vbWt0Od9Ux  Falling into your eyes Record      3636.0
# 1756    2lR5gm2BEy1PFxPSuyTWBU                            Boa       442.0
# 8486    42khMXWZYiyt9Yaw3lKgz5                           No 2      2176.0
# 10175   2QPBB9Vp5ZpcvLgbrnlNCc            Urban Funk Breaks 2       777.0
# 12333   0zmU4bGV5OmfBsOU9KPfxy                          Swing      1984.0
# ...                        ...                            ...         ...
# 105557  5HLT3oPj9pObEIKslHGmQd                      Bumfuzzle       368.0
# 107461  5Qe2ogGBgher2D1U1k7Ezc             Great Good Five Ok      2020.0
# 109013  2XWjPtKdi5sucFYtVav07d                            365       365.0
# 111519  3JZjPBwqL5F4PE55nm8iNV                       Geogaddi      1969.0
# 112313  36ROZuJyblakeB5BJijGjG                           1500      1500.0
#
# [98 rows x 3 columns]

# %%
statement_2 = f"""
SELECT artists, AVG(popularity) AS avg_popularity
FROM {database_name}.{table_name_csv}
GROUP BY artists
HAVING AVG(popularity) = 92
"""
print("SQL Answer", "\n")
df_sql_2 = pd.read_sql(statement_2, conn)
print(df_sql_2)
# Out:
# SQL Answer
#
# Empty DataFrame
# Columns: [artists, avg_popularity]
# Index: []

# %%
df_pds_2 = (
    df_all.groupby('artists')['popularity']
    .mean()
    .reset_index()
)

print("Pandas Answer", "\n")
df_pds_2 = df_pds_2[df_pds_2['popularity'] == 92]
print(df_pds_2)
# Out:
# Pandas Answer
#
# Empty DataFrame
# Columns: [artists, popularity]
# Index: []

# %%
statement_3 = f"""
SELECT track_genre, AVG(energy) AS avg_energy
FROM {database_name}.{table_name_csv}
GROUP BY track_genre
ORDER BY avg_energy DESC
LIMIT 10
"""

print("SQL Answer", "\n")
df_sql_3 = pd.read_sql(statement_3, conn)
print(df_sql_3)
# Out:
# SQL Answer
#
#   track_genre  avg_energy
# 0       0.436   2523428.0
# 1       0.473   2287542.0
# 2       0.848   1534315.0
# 3      0.0374   1452106.0
# 4      0.0345   1371693.0
# 5       0.417    899308.8
# 6      0.0832    693666.0
# 7      0.0578    610320.0
# 8       0.356    596956.0
# 9      0.0339    525000.0

# %%
df_pds_3 = (
    df_all.groupby('track_genre')['energy']
    .mean()
    .reset_index()
    .sort_values(by='energy', ascending=False)
    .head(10)
)

print("Pandas Answer", "\n")
print(df_pds_3)
# Out:
# Pandas Answer
#
#     track_genre     energy
# 454       0.436  2523428.0
# 475       0.473  2287542.0
# 688       0.848  1534315.0
# 55       0.0374  1452106.0
# 45       0.0345  1371693.0
# 441       0.417   899308.8
# 159      0.0832   693666.0
# 94       0.0578   610320.0
# 396       0.356   596956.0
# 42       0.0339   525000.0

# %%
statement_4 = f"""
SELECT COUNT(*) AS bad_bunny_track_count
FROM {database_name}.{table_name_csv}
WHERE artists LIKE '%Bad Bunny%'
"""

print("SQL Answer", "\n")
df_sql_4 = pd.read_sql(statement_4, conn)
print(df_sql_4)
# Out:
# SQL Answer
#
#    bad_bunny_track_count
# 0                      0

# %%
count_pds_4 = df_all['artists'].str.contains('Bad Bunny', case=False, na=False).sum()

print("Pandas Answer", "\n")
print(f"Bad Bunny track count: {count_pds_4}")
# Out:
# Pandas Answer
#
# Bad Bunny track count: 0

# %%
statement_5 = f"""
SELECT track_genre, MAX(popularity) AS max_track_popularity, AVG(popularity) AS avg_genre_popularity
FROM {database_name}.{table_name_csv}
GROUP BY track_genre
ORDER BY max_track_popularity DESC
LIMIT 10
"""

print("SQL Answer", "\n")
df_sql_5 = pd.read_sql(statement_5, conn)
print(df_sql_5)
# Out:
# SQL Answer
#
#   track_genre  max_track_popularity  avg_genre_popularity
# 0           4            20202020.0         150497.557143
# 1           3                2049.0            636.625000
# 2           1                 911.0            911.000000
# 3       0.943                   3.0              3.000000
# 4       0.771                   3.0              3.000000
# 5       0.597                   2.0              2.000000
# 6         0.0                   0.0              0.000000
# 7       0.278                   NaN                   NaN
# 8      84.853                   NaN                   NaN
# 9      102.44                   NaN                   NaN

# %%
df_pds_5 = (
    df_all.groupby('track_genre')['popularity']
    .agg(max_track_popularity='max', avg_genre_popularity='mean')
    .reset_index()
    .sort_values(by='max_track_popularity', ascending=False)
    .head(10)
)

print("Pandas Answer", "\n")
print(df_pds_5)
# Out:
# Pandas Answer
#
#          track_genre  max_track_popularity  avg_genre_popularity
# 3731               4            20202020.0         150497.557143
# 3727               3                2049.0            636.625000
# 784                1                 911.0            911.000000
# 645            0.771                   3.0              3.000000
# 742            0.943                   3.0              3.000000
# 548            0.597                   2.0              2.000000
# 12               0.0                   0.0              0.000000
# 0      Nina (Morgan)                   NaN                   NaN
# 1             -0.882                   NaN                   NaN
# 2            -13.299                   NaN                   NaN

# %%
# Release Resources

# %%
# %%html
#
# <p><b>Shutting down your kernel for this notebook to release resources.</b></p>
# <button class="sm-command-button" data-commandlinker-command="kernelmenu:shutdown" style="display:none;">Shutdown Kernel</button>
#
# <script>
# try {
#     els = document.getElementsByClassName("sm-command-button");
#     els[0].click();
# }
# catch(err) {
#     // NoOp
# }
# </script>

# %%
# %%javascript
#
# try {
#     Jupyter.notebook.save_checkpoint();
#     Jupyter.notebook.session.delete();
# }
# catch(err) {
#     // NoOp
# }
